# %% [markdown]
# ### Simple pretrained model test for summarization (distilbart)
# * this method splits the transcript into fixed sizes and summarizes each piece
# * doesn't seem very good...

# %%
# !pip install -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 34.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 36.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 12.0 MB/s eta 0:00:00

# %%
from transformers import pipeline

# %%
summarizer = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
result = "Hey this is eric johnson it's february eighteen twenty twenty one and this is the engineering key review at gitlab a so i've got number four in the agenda a which is a proposal to break up this meeting into for department keyervi ous occurrently this is engineering am development quality security and u acts infor structure and am support do their own views already i have the reasons why increase visibility able to go deeper a a increase the objectivity with which my reports can manage their groups allow me more time to focus on new markets and a allow me to shift in a more of a question asker mode than generating content and answering questions in these meetings a end da but to avoid adding three netnew meetings to stay coler's counters at propose be du a sort of two month rotation so monthuon development quality go mont to secure te anuax would go how do people feel about that proposal thinkin de gu comfer sations it's working bealy well um so i'm i'm supportive and the is is the smallest thing mayb we need for meetings amonth like itt the biggest apartment its superssential but you propose this idonteu i could see either ways or let stakement te prop osal go we'll try it and wila we can be flexible i mean tha development is larger maybe the go more frequent ly ersham plansapple will see how it to see hot it goes lright and thena i've got number five um which is sa we've got um arandy over all m mar rate and we also have r ind wider a mor rate both as a top level capiie for engineering so the difference between them in the simplest s ense is that arindy wie an mirate includes both community contributions and community and mars athe problems i see with this are that on n the wider emarate a thoh hen that includes internally an external emars it duplicates the overall emara which is aodin nerstaritery the wider emar rate should just be external right and an overoll should be narrow clus wider oh yo ike we say to wider community rirarit aka so there's of check the taxnomy lilly can you had can you confirm sitzry that's that sid's reasoning is my y understanding as well ye i believe water aam our rageous captures communiy contributions only a no internal and the measure dat is that like one of the most likely failure modes is that we lose the community well so riggeth er wiggeh cofi as is that am when you look at specific teem within the company there could be concontributions outside of that that aren't communi contributions they would be u cumi contributions by that group but effectively they're not from outside the companies that's wht we use wider to cin o reflect that and narrow is very specific to the team are you saying that if a some one in plan contributes to verify its fewt is wider not quite that a plan plan of verify o re just fine i dits when ye look at i like to developmen verses imperstructure imerstructure will oftentimes contribute to developments work but it won't be counted i as i ars uch a that's a that's a potential bit of funkiness that we should talk about separately i didn't have that in my sort of crutikue of is but that that doesn't nes surly make intuitive sense to me am so so then i think 'm part of my a cortique of this can be thrown out cause it's not as duplicative as i thought but i still think there's a problem with arindu wider a maray which is am this thing doesn't really move in part because it's ar it's a rate so it feels like the way to drive sap is  specifically drive communin the authors to contribute more than one am ar per month that's how this moves up because it's a it's a productivity rat like we internally and that doesn't asso they feel like the right thing ause there snares in which this goes up we've actually got less contributions over all and must contributos over all wa wawaa again so use your saying that arende witer am i rate is number mars pur external contributor oh my goodness that should not be the thing it should be contributions forget lap t member so to contre those the the the thing above the division is the external ones the thing below is the number of team members at gitlamp isthat the case slowly i'm checking writ now im i think l in i eerar o mertad he mem r or so unless we start calling people outside the company tea membered and it shouldn't be done the adturs clarifying here so o numerator as community contributions and then ar a denominator is a get laptei members sellsnap pur external a member so we so we've gat what would do ing their ericits ere nots trying to say how many how many mars to some one sent if they send something for saying how many mars from extra ol do we get for the size of our organization sorry have a childhood emergency outside the door ar so so that maybe explained o context behind is to contextis as we grow as a company we should make sure we wed keep to com munity i plake the logical thing is for the compunity to flat line and the size of the york to go in before you know it you've kind of outgrown the wider community yedident wuld m seeing as we we created this presephisicated taxonomy with prefixes and postpixes to talk about these things but in reality we've only got two of them and it's we keep forgetting and we have a hard time discussing this thing so i'd rather just name them simply some two names for what they are rather t en then using the taxonomy but also like in f i have the proposal of like what if we just tract as a cape ya f the percentage of total in ars that come from the community over time nd we would see that rap i love that i love that let's do that instead ebut the the thing the thing why we have this complex thing is b cause you can game that yet you want a game that you jist produce fewer andmars with the engineers sat gitlot so if you drive that really harness at tis is your noble one goal it'svery easy to chievious distell all your engineers to produce half yes so we have we have different metrics to prevent that from happening the same ma like support aseles an asac kind of buttress one another ah i think were were robust to that but simplifying this would make these conversations go he if you as is arsitio don't even understand them we went overboard to si whsham port if not underster om and i forgot and i was agreeing the stuff a sworning ut like there's a palm with us and then you just remend me of the contect sa i i can't bolove my i go mercentage that come from the community i love that it's what all are investors ask about let's do that aka co se am lily if ye can work with tha max too make that transition out egreat and i'll bold the one that otor talk him out et rumanermulsery thanks among the calsorrias o itle tre a time i we do have p eyes on de ra number of community an mars i we can  mke the shift and whider confirming from the definition living wide only counts for a community annd that's that's what the definition is co it so a number six then christopher sir i is looking up to see if i had the percentage chegraph cas i think we played around with us at one point and had a draufhter that um prolly about five months back if i can remember lily am a i just enough way i a t month of february if you are looking at any paticular metric septucing development at ema rate ah we haven't had up dates in four days others ough apparently all laggish ue that's been a problematica a for the datotam to biscly getta obdate mes mesate dde mentrics and thee working on that g i'm sorry mac ye got the next one ah say i i e des em som cale the on an te inmitigation the the lag later on a unto unto seven a we can  a cirdev whar i in addition to that sleep ye sis i am sorry  i got want to tis touch on the postcrasts y replication issue their ro quick imi been try to get my arms wrapped around it an do we have the right attention to this this is kind of ericotonouf you are commenting on a hinting towards this in the last meeting aroun"

# %%
num_iters = int(len(result)/1000)
summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  print("input text \n" + result[start:end])
  out = summarizer(result[start:end])
  out = out[0]
  out = out['summary_text']
  print("Summarized text\n"+out)
  summarized_text.append(out)

#print(summarized_text)
# Out:
# input text
# ...

# %%
len(str(summarized_text))
# Out:
# 2595

# %%
str(summarized_text)
# Out:
# '[" i\'ve got number four in the agenda a which is a proposal to break up this meeting into for department keyervi ous occurrently this is engineering am development quality security and u acts infor structure and am support do their own views already i have the reasons why increase visibility able to go deeper .", " The development is larger maybe the go more frequent ly ersham plansapple will see how it to see hot it goes lright and thena i\'ve got number five um which is sa we\'ve got um arandy over all m mar rate and we also have r ind wider a mor rate both as a top level capiie for engineering .", " Water aam our rageous captures communiy contributions only a no internal and the measure dat is that like one of the most likely failure modes is that we lose the community well so riggeth er wiggeh cofi as is that am when you look at specific teem within the company there could be concontributions outside of that that aren\'t communi contributions .", " i still think there\'s a prob
# ...

# %%
# summarize a specific group - cannot pass the entire text at once
idx = 1
summary = summarizer(result[idx*1024:(idx+1)*1024])
print(summary)
# Out:
# [{'summary_text': " The development is larger maybe the go more frequent ly ersham plansapple will see how it to see hot it goes lright and thena i've got number five um which is sa we've got um arandy over all m mar rate and we also have r ind wider a mor rate both as a top level capiie for engineering ."}]

# %% [markdown]
# ### Source
# * https://www.youtube.com/watch?v=3V-MJhJvRWg
# * https://colab.research.google.com/drive/17lEoIPVozCmaAUHXLSkJSWEtKVnXEMsf?usp=sharing#scrollTo=31mkg8GbcddH

# %% [markdown]
# ### Trying different model - LED

# %%
long_text = "Hey this is eric johnson it's february eighteen twenty twenty one and this is the engineering key review at gitlab a so i've got number four in the agenda a which is a proposal to break up this meeting into for department keyervi ous occurrently this is engineering am development quality security and u acts infor structure and am support do their own views already i have the reasons why increase visibility able to go deeper a a increase the objectivity with which my reports can manage their groups allow me more time to focus on new markets and a allow me to shift in a more of a question asker mode than generating content and answering questions in these meetings a end da but to avoid adding three netnew meetings to stay coler's counters at propose be du a sort of two month rotation so monthuon development quality go mont to secure te anuax would go how do people feel about that proposal thinkin de gu comfer sations it's working bealy well um so i'm i'm supportive and the is is the smallest thing mayb we need for meetings amonth like itt the biggest apartment its superssential but you propose this idonteu i could see either ways or let stakement te prop osal go we'll try it and wila we can be flexible i mean tha development is larger maybe the go more frequent ly ersham plansapple will see how it to see hot it goes lright and thena i've got number five um which is sa we've got um arandy over all m mar rate and we also have r ind wider a mor rate both as a top level capiie for engineering so the difference between them in the simplest s ense is that arindy wie an mirate includes both community contributions and community and mars athe problems i see with this are that on n the wider emarate a thoh hen that includes internally an external emars it duplicates the overall emara which is aodin nerstaritery the wider emar rate should just be external right and an overoll should be narrow clus wider oh yo ike we say to wider community rirarit aka so there's of check the taxnomy lilly can you had can you confirm sitzry that's that sid's reasoning is my y understanding as well ye i believe water aam our rageous captures communiy contributions only a no internal and the measure dat is that like one of the most likely failure modes is that we lose the community well so riggeth er wiggeh cofi as is that am when you look at specific teem within the company there could be concontributions outside of that that aren't communi contributions they would be u cumi contributions by that group but effectively they're not from outside the companies that's wht we use wider to cin o reflect that and narrow is very specific to the team are you saying that if a some one in plan contributes to verify its fewt is wider not quite that a plan plan of verify o re just fine i dits when ye look at i like to developmen verses imperstructure imerstructure will oftentimes contribute to developments work but it won't be counted i as i ars uch a that's a that's a potential bit of funkiness that we should talk about separately i didn't have that in my sort of crutikue of is but that that doesn't nes surly make intuitive sense to me am so so then i think 'm part of my a cortique of this can be thrown out cause it's not as duplicative as i thought but i still think there's a problem with arindu wider a maray which is am this thing doesn't really move in part because it's ar it's a rate so it feels like the way to drive sap is  specifically drive communin the authors to contribute more than one am ar per month that's how this moves up because it's a it's a productivity rat like we internally and that doesn't asso they feel like the right thing ause there snares in which this goes up we've actually got less contributions over all and must contributos over all wa wawaa again so use your saying that arende witer am i rate is number mars pur external contributor oh my goodness that should not be the thing it should be contributions forget lap t member so to contre those the the the thing above the division is the external ones the thing below is the number of team members at gitlamp isthat the case slowly i'm checking writ now im i think l in i eerar o mertad he mem r or so unless we start calling people outside the company tea membered and it shouldn't be done the adturs clarifying here so o numerator as community contributions and then ar a denominator is a get laptei members sellsnap pur external a member so we so we've gat what would do ing their ericits ere nots trying to say how many how many mars to some one sent if they send something for saying how many mars from extra ol do we get for the size of our organization sorry have a childhood emergency outside the door ar so so that maybe explained o context behind is to contextis as we grow as a company we should make sure we wed keep to com munity i plake the logical thing is for the compunity to flat line and the size of the york to go in before you know it you've kind of outgrown the wider community yedident wuld m seeing as we we created this presephisicated taxonomy with prefixes and postpixes to talk about these things but in reality we've only got two of them and it's we keep forgetting and we have a hard time discussing this thing so i'd rather just name them simply some two names for what they are rather t en then using the taxonomy but also like in f i have the proposal of like what if we just tract as a cape ya f the percentage of total in ars that come from the community over time nd we would see that rap i love that i love that let's do that instead ebut the the thing the thing why we have this complex thing is b cause you can game that yet you want a game that you jist produce fewer andmars with the engineers sat gitlot so if you drive that really harness at tis is your noble one goal it'svery easy to chievious distell all your engineers to produce half yes so we have we have different metrics to prevent that from happening the same ma like support aseles an asac kind of buttress one another ah i think were were robust to that but simplifying this would make these conversations go he if you as is arsitio don't even understand them we went overboard to si whsham port if not underster om and i forgot and i was agreeing the stuff a sworning ut like there's a palm with us and then you just remend me of the contect sa i i can't bolove my i go mercentage that come from the community i love that it's what all are investors ask about let's do that aka co se am lily if ye can work with tha max too make that transition out egreat and i'll bold the one that otor talk him out et rumanermulsery thanks among the calsorrias o itle tre a time i we do have p eyes on de ra number of community an mars i we can  mke the shift and whider confirming from the definition living wide only counts for a community annd that's that's what the definition is co it so a number six then christopher sir i is looking up to see if i had the percentage chegraph cas i think we played around with us at one point and had a draufhter that um prolly about five months back if i can remember lily am a i just enough way i a t month of february if you are looking at any paticular metric septucing development at ema rate ah we haven't had up dates in four days others ough apparently all laggish ue that's been a problematica a for the datotam to biscly getta obdate mes mesate dde mentrics and thee working on that g i'm sorry mac ye got the next one ah say i i e des em som cale the on an te inmitigation the the lag later on a unto unto seven a we can  a cirdev whar i in addition to that sleep ye sis i am sorry  i got want to tis touch on the postcrasts y replication issue their ro quick imi been try to get my arms wrapped around it an do we have the right attention to this this is kind of ericotonouf you are commenting on a hinting towards this in the last meeting aroun"

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

model_name = "allenai/led-large-16384-arxiv" # would want to take the base model and fine tune it with AMI dataset
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

pipe = pipeline("text2text-generation", model=model, tokenizer=tokenizer)#, device=0)

generated_text = pipe(
    long_text, 
    truncation=True, 
    max_length=256, 
    no_repeat_ngram_size=5, 
    num_beams=3, 
    early_stopping=True
    )

# %%
generated_text
# Out:
# [{'generated_text': " this is the engineering key review at gitlab a so i've got number four in the agenda a which is a proposal to break up this meeting into for department keyervi ous occurrently this is engineering am development quality security and u acts infor structure and am support do their own views already i have the reasons why increase visibility able to go deeper a a increase the objectivity with which my reports can manage their groups allow me more time to focus on new markets and a a allow me to shift in a more of a question asker mode than generating content and answering questions in these meetings a end da but to avoid adding three netnew meetings to stay coler s counters at propose be du a sort of two month rotation so monthuon development quality go mont to secure te anuax would go how do people feel about that proposal thinkin de gu comfer sations it s working bealy well um so i'm i'm supportive and the is is the smallest thing mayb we need for meetings amonth 
# ...

# %% [markdown]
# ### Sources
# * https://huggingface.co/allenai/led-large-16384
# * https://discuss.huggingface.co/t/summarization-pipeline-on-long-text/27752
# * https://colab.research.google.com/drive/12LjJazBl7Gam0XBPy_y0CTOJZeZ34c2v?usp=sharing
# * https://huggingface.co/docs/transformers/model_doc/led

# %% [markdown]
# ### Trying out T5

# %%
# !pip install torch
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 77.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 27.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 86.8 MB/s eta 0:00:00
# ...

# %%
text = "Hey this is eric johnson it's february eighteen twenty twenty one and this is the engineering key review at gitlab a so i've got number four in the agenda a which is a proposal to break up this meeting into for department keyervi ous occurrently this is engineering am development quality security and u acts infor structure and am support do their own views already i have the reasons why increase visibility able to go deeper a a increase the objectivity with which my reports can manage their groups allow me more time to focus on new markets and a allow me to shift in a more of a question asker mode than generating content and answering questions in these meetings a end da but to avoid adding three netnew meetings to stay coler's counters at propose be du a sort of two month rotation so monthuon development quality go mont to secure te anuax would go how do people feel about that proposal thinkin de gu comfer sations it's working bealy well um so i'm i'm supportive and the is is the smallest thing mayb we need for meetings amonth like itt the biggest apartment its superssential but you propose this idonteu i could see either ways or let stakement te prop osal go we'll try it and wila we can be flexible i mean tha development is larger maybe the go more frequent ly ersham plansapple will see how it to see hot it goes lright and thena i've got number five um which is sa we've got um arandy over all m mar rate and we also have r ind wider a mor rate both as a top level capiie for engineering so the difference between them in the simplest s ense is that arindy wie an mirate includes both community contributions and community and mars athe problems i see with this are that on n the wider emarate a thoh hen that includes internally an external emars it duplicates the overall emara which is aodin nerstaritery the wider emar rate should just be external right and an overoll should be narrow clus wider oh yo ike we say to wider community rirarit aka so there's of check the taxnomy lilly can you had can you confirm sitzry that's that sid's reasoning is my y understanding as well ye i believe water aam our rageous captures communiy contributions only a no internal and the measure dat is that like one of the most likely failure modes is that we lose the community well so riggeth er wiggeh cofi as is that am when you look at specific teem within the company there could be concontributions outside of that that aren't communi contributions they would be u cumi contributions by that group but effectively they're not from outside the companies that's wht we use wider to cin o reflect that and narrow is very specific to the team are you saying that if a some one in plan contributes to verify its fewt is wider not quite that a plan plan of verify o re just fine i dits when ye look at i like to developmen verses imperstructure imerstructure will oftentimes contribute to developments work but it won't be counted i as i ars uch a that's a that's a potential bit of funkiness that we should talk about separately i didn't have that in my sort of crutikue of is but that that doesn't nes surly make intuitive sense to me am so so then i think 'm part of my a cortique of this can be thrown out cause it's not as duplicative as i thought but i still think there's a problem with arindu wider a maray which is am this thing doesn't really move in part because it's ar it's a rate so it feels like the way to drive sap is  specifically drive communin the authors to contribute more than one am ar per month that's how this moves up because it's a it's a productivity rat like we internally and that doesn't asso they feel like the right thing ause there snares in which this goes up we've actually got less contributions over all and must contributos over all wa wawaa again so use your saying that arende witer am i rate is number mars pur external contributor oh my goodness that should not be the thing it should be contributions forget lap t member so to contre those the the the thing above the division is the external ones the thing below is the number of team members at gitlamp isthat the case slowly i'm checking writ now im i think l in i eerar o mertad he mem r or so unless we start calling people outside the company tea membered and it shouldn't be done the adturs clarifying here so o numerator as community contributions and then ar a denominator is a get laptei members sellsnap pur external a member so we so we've gat what would do ing their ericits ere nots trying to say how many how many mars to some one sent if they send something for saying how many mars from extra ol do we get for the size of our organization sorry have a childhood emergency outside the door ar so so that maybe explained o context behind is to contextis as we grow as a company we should make sure we wed keep to com munity i plake the logical thing is for the compunity to flat line and the size of the york to go in before you know it you've kind of outgrown the wider community yedident wuld m seeing as we we created this presephisicated taxonomy with prefixes and postpixes to talk about these things but in reality we've only got two of them and it's we keep forgetting and we have a hard time discussing this thing so i'd rather just name them simply some two names for what they are rather t en then using the taxonomy but also like in f i have the proposal of like what if we just tract as a cape ya f the percentage of total in ars that come from the community over time nd we would see that rap i love that i love that let's do that instead ebut the the thing the thing why we have this complex thing is b cause you can game that yet you want a game that you jist produce fewer andmars with the engineers sat gitlot so if you drive that really harness at tis is your noble one goal it'svery easy to chievious distell all your engineers to produce half yes so we have we have different metrics to prevent that from happening the same ma like support aseles an asac kind of buttress one another ah i think were were robust to that but simplifying this would make these conversations go he if you as is arsitio don't even understand them we went overboard to si whsham port if not underster om and i forgot and i was agreeing the stuff a sworning ut like there's a palm with us and then you just remend me of the contect sa i i can't bolove my i go mercentage that come from the community i love that it's what all are investors ask about let's do that aka co se am lily if ye can work with tha max too make that transition out egreat and i'll bold the one that otor talk him out et rumanermulsery thanks among the calsorrias o itle tre a time i we do have p eyes on de ra number of community an mars i we can  mke the shift and whider confirming from the definition living wide only counts for a community annd that's that's what the definition is co it so a number six then christopher sir i is looking up to see if i had the percentage chegraph cas i think we played around with us at one point and had a draufhter that um prolly about five months back if i can remember lily am a i just enough way i a t month of february if you are looking at any paticular metric septucing development at ema rate ah we haven't had up dates in four days others ough apparently all laggish ue that's been a problematica a for the datotam to biscly getta obdate mes mesate dde mentrics and thee working on that g i'm sorry mac ye got the next one ah say i i e des em som cale the on an te inmitigation the the lag later on a unto unto seven a we can  a cirdev whar i in addition to that sleep ye sis i am sorry  i got want to tis touch on the postcrasts y replication issue their ro quick imi been try to get my arms wrapped around it an do we have the right attention to this this is kind of ericotonouf you are commenting on a hinting towards this in the last meeting aroun"

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model = AutoModelForSeq2SeqLM.from_pretrained('t5-base')

tokenizer = AutoTokenizer.from_pretrained('t5-base')

tokens_input = tokenizer.encode("summarize: "+text, return_tensors='pt', 
                                max_length=tokenizer.model_max_length, 
                                truncation=True)

summary_ids = model.generate(tokens_input, min_length=80,
                             max_length=150,
                             length_penalty=20, 
                             num_beams=2)

summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
# Out:
# ...
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
print(summary) # this is surprisingly good but only works for 512 characters at a time
# Out:
# eric johnson has a proposal to break up gitlab meetings into departments. he says this will give him more time to focus on new markets. he also wants to see a two month rotation of meetings. johnson says he's supportive of the idea. he says it's the smallest thing we need for meetings amonth. he also wants to see a more flexible approach to meetings. johnson: 'it's a good idea..................

# %%
len(tokenizer(text)['input_ids'])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (2235 > 512). Running this sequence through the model will result in indexing errors
# 2235

# %%
tokenizer.model_max_length
# Out:
# 512

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model = AutoModelForSeq2SeqLM.from_pretrained('t5-base')

tokenizer = AutoTokenizer.from_pretrained('t5-base')

num_iters = int(len(text)/1000)
summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  print("input text \n" + text[start:end])

  tokens_input = tokenizer.encode("summarize: "+text[start:end], return_tensors='pt', 
                                  max_length=tokenizer.model_max_length, 
                                  truncation=True)

  summary_ids = model.generate(tokens_input, min_length=80,
                              max_length=150,
                              length_penalty=20, 
                              num_beams=2)

  summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)


  print("Summarized text\n"+summary)
  summarized_text.append(summary)

#print(summarized_text)
# Out:
# ...
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# input text
# ...

# %% [markdown]
# ### Sources
# * https://github.com/louisteo9/t5-text-summarizer/blob/master/T5%20Text%20Summarizer.ipynb

# %% [markdown]
# ### Seems like spell check is needed first

# %%
# !pip install transformers[sentencepiece]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 40.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.9 MB/s eta 0:00:00
# ...

# %%
text = "Hey this is eric johnson it's february eighteen twenty twenty one and this is the engineering key review at gitlab a so i've got number four in the agenda a which is a proposal to break up this meeting into for department keyervi ous occurrently this is engineering am development quality security and u acts infor structure and am support do their own views already i have the reasons why increase visibility able to go deeper a a increase the objectivity with which my reports can manage their groups allow me more time to focus on new markets and a allow me to shift in a more of a question asker mode than generating content and answering questions in these meetings a end da but to avoid adding three netnew meetings to stay coler's counters at propose be du a sort of two month rotation so monthuon development quality go mont to secure te anuax would go how do people feel about that proposal thinkin de gu comfer sations it's working bealy well um so i'm i'm supportive and the is is the smallest thing mayb we need for meetings amonth like itt the biggest apartment its superssential but you propose this idonteu i could see either ways or let stakement te prop osal go we'll try it and wila we can be flexible i mean tha development is larger maybe the go more frequent ly ersham plansapple will see how it to see hot it goes lright and thena i've got number five um which is sa we've got um arandy over all m mar rate and we also have r ind wider a mor rate both as a top level capiie for engineering so the difference between them in the simplest s ense is that arindy wie an mirate includes both community contributions and community and mars athe problems i see with this are that on n the wider emarate a thoh hen that includes internally an external emars it duplicates the overall emara which is aodin nerstaritery the wider emar rate should just be external right and an overoll should be narrow clus wider oh yo ike we say to wider community rirarit aka so there's of check the taxnomy lilly can you had can you confirm sitzry that's that sid's reasoning is my y understanding as well ye i believe water aam our rageous captures communiy contributions only a no internal and the measure dat is that like one of the most likely failure modes is that we lose the community well so riggeth er wiggeh cofi as is that am when you look at specific teem within the company there could be concontributions outside of that that aren't communi contributions they would be u cumi contributions by that group but effectively they're not from outside the companies that's wht we use wider to cin o reflect that and narrow is very specific to the team are you saying that if a some one in plan contributes to verify its fewt is wider not quite that a plan plan of verify o re just fine i dits when ye look at i like to developmen verses imperstructure imerstructure will oftentimes contribute to developments work but it won't be counted i as i ars uch a that's a that's a potential bit of funkiness that we should talk about separately i didn't have that in my sort of crutikue of is but that that doesn't nes surly make intuitive sense to me am so so then i think 'm part of my a cortique of this can be thrown out cause it's not as duplicative as i thought but i still think there's a problem with arindu wider a maray which is am this thing doesn't really move in part because it's ar it's a rate so it feels like the way to drive sap is  specifically drive communin the authors to contribute more than one am ar per month that's how this moves up because it's a it's a productivity rat like we internally and that doesn't asso they feel like the right thing ause there snares in which this goes up we've actually got less contributions over all and must contributos over all wa wawaa again so use your saying that arende witer am i rate is number mars pur external contributor oh my goodness that should not be the thing it should be contributions forget lap t member so to contre those the the the thing above the division is the external ones the thing below is the number of team members at gitlamp isthat the case slowly i'm checking writ now im i think l in i eerar o mertad he mem r or so unless we start calling people outside the company tea membered and it shouldn't be done the adturs clarifying here so o numerator as community contributions and then ar a denominator is a get laptei members sellsnap pur external a member so we so we've gat what would do ing their ericits ere nots trying to say how many how many mars to some one sent if they send something for saying how many mars from extra ol do we get for the size of our organization sorry have a childhood emergency outside the door ar so so that maybe explained o context behind is to contextis as we grow as a company we should make sure we wed keep to com munity i plake the logical thing is for the compunity to flat line and the size of the york to go in before you know it you've kind of outgrown the wider community yedident wuld m seeing as we we created this presephisicated taxonomy with prefixes and postpixes to talk about these things but in reality we've only got two of them and it's we keep forgetting and we have a hard time discussing this thing so i'd rather just name them simply some two names for what they are rather t en then using the taxonomy but also like in f i have the proposal of like what if we just tract as a cape ya f the percentage of total in ars that come from the community over time nd we would see that rap i love that i love that let's do that instead ebut the the thing the thing why we have this complex thing is b cause you can game that yet you want a game that you jist produce fewer andmars with the engineers sat gitlot so if you drive that really harness at tis is your noble one goal it'svery easy to chievious distell all your engineers to produce half yes so we have we have different metrics to prevent that from happening the same ma like support aseles an asac kind of buttress one another ah i think were were robust to that but simplifying this would make these conversations go he if you as is arsitio don't even understand them we went overboard to si whsham port if not underster om and i forgot and i was agreeing the stuff a sworning ut like there's a palm with us and then you just remend me of the contect sa i i can't bolove my i go mercentage that come from the community i love that it's what all are investors ask about let's do that aka co se am lily if ye can work with tha max too make that transition out egreat and i'll bold the one that otor talk him out et rumanermulsery thanks among the calsorrias o itle tre a time i we do have p eyes on de ra number of community an mars i we can  mke the shift and whider confirming from the definition living wide only counts for a community annd that's that's what the definition is co it so a number six then christopher sir i is looking up to see if i had the percentage chegraph cas i think we played around with us at one point and had a draufhter that um prolly about five months back if i can remember lily am a i just enough way i a t month of february if you are looking at any paticular metric septucing development at ema rate ah we haven't had up dates in four days others ough apparently all laggish ue that's been a problematica a for the datotam to biscly getta obdate mes mesate dde mentrics and thee working on that g i'm sorry mac ye got the next one ah say i i e des em som cale the on an te inmitigation the the lag later on a unto unto seven a we can  a cirdev whar i in addition to that sleep ye sis i am sorry  i got want to tis touch on the postcrasts y replication issue their ro quick imi been try to get my arms wrapped around it an do we have the right attention to this this is kind of ericotonouf you are commenting on a hinting towards this in the last meeting aroun"

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Bhuvana/t5-base-spellchecker")

model = AutoModelForSeq2SeqLM.from_pretrained("Bhuvana/t5-base-spellchecker")


def correct(inputs):
    input_ids = tokenizer.encode(inputs,return_tensors='pt')
    sample_output = model.generate(
        input_ids,
        do_sample=True,
        max_length=512,
        top_p=0.99,
        num_return_sequences=1
    )
    res = tokenizer.decode(sample_output[0], skip_special_tokens=True)
    return res

corrected_text = ""

num_iters = int(len(text)/512)
for i in range(0, num_iters + 1):
  start = 0
  start = i * 512
  end = (i + 1) * 512
  x = correct(text[start:end])
  corrected_text += x

print(corrected_text)
# Out:
# is the engineering key review at gitlab a so i have got number four in the agenda a which is a proposal to break up this meeting into for department keyervi ous currently this is engineering am development quality security and u acts infor structure and am support to their own views already i have the reasons why increase visibility able to go deeper a a increase the objectivity with which my reports can manage their groups allow me
# a allow me to shift in a more of a question asker mode than generating content and answering questions in these meetings a end da but to avoid adding three netnew meetings to stay coler's counters at propose be du a sort of two month rotation so monthuon development quality go mont to secure te anuax would go how do people feel about that proposal thinkin de gu comfer sations it was working pretty well um so i m i m supportive and the is is the smallest thing maine we need
# ...

# %%
better_text = "is the engineering key review at gitlab a so i have got number four in the agenda a which is a proposal to break up this meeting into for department keyervi ous currently this is engineering am development quality security and u acts infor structure and am support to their own views already i have the reasons why increase visibility able to go deeper a a increase the objectivity with which my reports can manage their groups allow mea allow me to shift in a more of a question asker mode than generating content and answering questions in these meetings a end da but to avoid adding three netnew meetings to stay coler's counters at propose be du a sort of two month rotation so monthuon development quality go mont to secure te anuax would go how do people feel about that proposal thinkin de gu comfer sations it was working pretty well um so i m i m supportive and the is is the smallest thing maine we need ersham plansapple will see how it to see hot it goes right and thena i've got number five us which is so we ve got us arandy over all m mar rate and we also have r and wider a mor rate both as a top level city for engineering so the difference betweenn their in the simplest s ense is that arindy wie an mirate includes both community contributions and community and mars athe problems i see with this are that on n the wider emarate a thoh hen that includes internally an external emars it duplicates the overall emara which is aodin nerstaritery the wider emar rate should just be external right and an overoll should be narrow clus wider oh yo ike we say to wider community rirarit akathat way is my y understanding as well ye i believe water am our rageous captures communiy contributions only a no internal and the measure dat is that like one of the most likely failure modes is that we lose the community well so riggeth er wiggeth cofi as is that am when you look at specific teem within the company there could be concontributions outside of that that arennt communi contributions they would be u cumi contributions by that group but effectively theyif a some one in plan contributes to verify its result is wider not quite that a plan plan of verify o re just fine i dits when we look at i like to developmen verses imperstructure imerstructure will oftentimes contribute to developments work but it won't be counted i as i am uch a that s a that's a potential bit of funkiness that we should talk about separately i didn't have that in my sortof crutikue of is but that that doesn't nes surly make intuitive sense to me am so so then i think i think i think'm part of my a cortique of this can be thrown out cause it's not as duplicative as i thought but i still think there s a problem with arindu wider a matrix which is am this thing doesn't nes surly make intuitive sense to me am so so then i think i think'm part of my a cortique of this can be thrown out cause itctivity rat like we internally and that doesn't asso they feel like the right thing ause there snares in which this goes up we've actually got less contributions over all and must contributos over all wa wawaa again so use your saying that arende witer am i rate is number mars pur external contributor oh my goodness that should not be the thing it should be contributions forget lap t member so to contre those the the the thing above the division is the external ones the thing below is the number of team memi don t think l in i eerar o mertad he mem r or so unless we start calling people outside the company tea membered and it shouldn't be done the indicators clarifying here so o numerator is a get laptei members sellsnap pur external a member so we so we've got what would do ing their errors are nots trying to say how many how many mars to some one sent if they send something for saying how many marsoh extra oh do we get for the size of our organization sorry have a childhood emergency outside the door ar so so that maybe explained o context behind is to contextis as we grow as a company we should make sure we wed keep to com munity i place the logical thing is for the compunity to flat line and the size of the york to go in before you know it you ve kind of outgrown the wider community resident would m seeing as we we created this prephisicated taxonomy with prefixes and postfixes to talk about thesei have the proposal of like what if we just tract as a cape ya y the percentage of total in ars that come from the community over time nd we would see that rap i love that i love that let's do that instead ebut the the thing the thing why we have this complex thing is b cause you can game that yet you want a game that you jist produce fewer andmars with the engineers sat gitlot so if you drive that really harness at tis is your noble one goal it'svery easy to chievious distell all your engineers to produce half yes so we have we have different metrics to prevent that from happening the same ma like support aseles an asac kind of buttress one another ah i think were were robust to that but simplifying this would make these conversations go he if you as is at i thinki even understand them we went overboard to si whsham port if not underster om and i forgot and i was agreeing the stuff a sworning ut like there s a palm with us and then you just remark me of the project sa i i i can't bolove my i go mercentage that come from the community i love that it s what all are investors ask about let s do that aka co si am lis itle tre a time i we do have p eyes on de ra number of community an mars i we can make the shift and whider confirming from the definition living wide only counts for a community and that's that's what the definition is co it so a number six then christopher sir i is looking up to see if i had the percentage chegraph cas i think we played around with us at one point and had a draufhter thathooking at any paticular metric septucing development at ema rate ah we haven't had up dates in four days others ough apparently all laggish ue that's been a problematica a for the datotam to biscly getta obdate mes mesate dde mentrics and then working on that g i m sorry mac ye got the next one ah say i i e e o dution issue their do quick im been try to get my arms wrapped around it and do we have the right attention to this this is kind of ericotonouf you are commenting on a hinting towards this in the last meeting around"

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

model_name = "allenai/led-large-16384-arxiv" # would want to take the base model and fine tune it with AMI dataset
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

pipe = pipeline("text2text-generation", model=model, tokenizer=tokenizer)#, device=0)

generated_text = pipe(
    better_text, 
    truncation=True, 
    max_length=256, 
    no_repeat_ngram_size=5, 
    num_beams=3, 
    early_stopping=True
    )

# %%
generated_text
# Out:
# [{'generated_text': " this is the engineering key review at gitlab a so i have got number four in the agenda a which is a proposal to break up this meeting into for department keyervi ous currently this is engineering am development quality security and u acts infor structure and am support to their own views already i have the reasons why increase visibility able to go deeper a a increase the objectivity with which my reports can manage their groups allow mea allow me to shift in a more of a question asker mode than generating content and answering questions in these meetings a end da but to avoid adding three netnew meetings to stay coler s counters at propose be du a sort of two month rotation so monthuon development quality go mont to secure te anuax would go how do people feel about that proposal thinkin de gu comfer sations it was working pretty well um so i m i m supportive and the is is the smallest thing maine we need ersham plansapple will see how it to see hot it goes righ
# ...

# %% [markdown]
# ### Finetuning a summarization model with AMI summarization dataset
#
# * https://huggingface.co/datasets/knkarthick/AMI

# %%
from datasets import load_dataset

# If the dataset is gated/private, make sure you have run huggingface-cli login
dataset = load_dataset("knkarthick/AMI")
